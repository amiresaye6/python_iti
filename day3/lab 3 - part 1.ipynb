# %% [markdown]
# ### **1) Calculator**

# %% [markdown]
# Please write a program which asks the user for two numbers and an operation. If the operation is add, multiply or subtract, the program should calculate and print out the result of the operation with the given numbers. If the user types in anything else, the program should print out nothing.

# %% [markdown]
# *Some examples of expected behaviour:*

# %% [markdown]
# Number 1: 10<br>
# Number 2: 17<br>
# Operation: add<br>
#
# 10 + 17 = 27

# %% [markdown]
# Number 1: 4<br>
# Number 2: 6<br>
# Operation: multiply<br>
#
# 4 * 6 = 24

# %%
def program():
    n1 = float(input("Number 1: "))
    n2 = float(input("Number 2: "))
    op = input("Operation: ")
    if (op == 'multiply'):
        print(f'{n1} * {n2} = {n1 * n2}')
    elif (op == 'add'):
        print(f'{n1} + {n2} = {n1 + n2}')
    elif (op == 'subtract'):
        print(f'{n1} - {n2} = {n1 - n2}')

program()

# %% [markdown]
# ### **2) Daily wages**

# %% [markdown]
# Please write a program which asks for the hourly wage, hours worked, and the day of the week. The program should then print out the daily wages, which equal hourly wage multiplied by hours worked, except on Sundays when the hourly wage is doubled.

# %% [markdown]
# Hourly wage: 8.5<br>
# Hours worked: 3<br>
# Day of the week: Monday<br>
# Daily wages: 25.5 euros<br>

# %% [markdown]
# Hourly wage: 12.5<br>
# Hours worked: 10<br>
# Day of the week: Sunday<br>
# Daily wages: 250.0 euros<br>

# %%
def daileyWages():
    hwage = float(input("Hourly wage:"))
    hwork = float(input("Hours worked:"))
    dow = input("Day of the week:")

    dayesOfTheWeek = {
        "Saturday": 1,
        "Sunday": 2,
        "Monday": 1,
        "Tuesday": 1,
        "Wednesday": 1,
        "Thursday": 1,
        "Friday": 1,
    }

    if (dow not in dayesOfTheWeek):
        print("invalidn day of the week")
        return
    
    print(f'Daily wages: {hwage * hwork * dayesOfTheWeek[dow]} euros')


daileyWages()

# %% [markdown]
# ### **3) FizzBuzz**

# %% [markdown]
# Please write a program which asks the user for an integer number. If the number is divisible by three, the program should print out Fizz. If the number is divisible by five, the program should print out Buzz. If the number is divisible by both three and five, the program should print out FizzBuzz.

# %% [markdown]
# *Some examples of expected behaviour:*

# %% [markdown]
# Number: 9<br>
# Fizz

# %% [markdown]
# Number: 20<br>
# Buzz

# %% [markdown]
# Number: 7

# %% [markdown]
# Number: 45<br/>
# FizzBuzz

# %%
def fizzBuzz():
    num = int(input("Number: "))
    if (num % 3 == 0):
        if (num % 5 == 0):
            print("FizzBuzz")
        else:
            print("Fizz")
    elif (num% 5 == 0):
        print("Buzz")

fizzBuzz()

# %% [markdown]
# ### **4) PIN and number of attempts**

# %% [markdown]
# Please write a program which keeps asking the user for a PIN code until they type in the correct one, which is 4321. The program should then print out the number of times the user tried different codes.

# %% [markdown]
# PIN: 3245<br>
# Wrong<br>
# PIN: 1234<br>
# Wrong<br>
# PIN: 0000<br>
# Wrong<br>
# PIN: 4321<br>
# Correct! It took you 4 attempts

# %% [markdown]
# **If the user gets it right on the first try,** the program should print out something a bit different:

# %% [markdown]
# PIN: 4321<br>
# Correct! It only took you one single attempt!

# %%
def login():
    password = "4321"
    flag = True
    count = 0
    while(flag):
        logPass = input("PIN: ")
        count += 1
        if (logPass == password):
            if (count == 1):
                print("Correct! it only took you one single attempt!")
            else:
                print(f"Correct! it took you {count} attempts")
            flag = False
login()
# Out:
# Correct! it only took you one single attempt!

# %% [markdown]
# ### **5) write a function which has an input of string from user then it return the same string reversed.**

# %%
def revStr(str):
    tmp = ""
    for i in range(len(str) - 1, -1, -1):
        tmp+= str[i]
    return (str,tmp)
revStr("amir alsayed")
# Out:
# ('amir alsayed', 'deyasla rima')

# %% [markdown]
# ### **6) Please write a function named greatest_number, which takes three**
# arguments. The function returns the greatest in value of the three.
# [without using max function, and solve it in two ways]

# %%
def greatest_number(a, b, c):
    if (a >= b):
        if (a >= c):
            return a
        else:
            return c
    elif (b >= c):
        return b
    return c
def greatest_number2(a, b, c):
    higherVal = a
    if b > higherVal:
        higherVal = b
    if c > higherVal:
        higherVal = c
    return higherVal

print(greatest_number(1, 2, 4))
print(greatest_number(3, 5, 4))
print(greatest_number2(3, 1, 0))
# Out:
# 4
# 5
# 3

# %% [markdown]
# ### **7) Write a function sum_series(n) that calculates the sum of the**
# series:
# 1 - 2 + 3 - 4 + 5 - ... up to n

# %%
def sum_series(n):
    res = 0
    for i in range(1, n + 1, 1):
        if i % 2 == 0:
            res -= i
        else:
            res += i
    return res

sum_series(5)
# Out:
# 3

# %% [markdown]
# ### **8) Write a Python function to calculate the factorial of a number (a**
# non-negative integer). The function accepts the number as an
# argument.

# %%
def fact(n):
    res = 1

    if (not isinstance(n, int)):
        print("invalidn input")
        return

    if (n < 0):
        print("must be positive number")
        return

    for i in range(1, n + 1, 1):
        res *= i
    return res

fact(5)
# Out:
# 120
